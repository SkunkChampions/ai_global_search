# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
filepath = "../data/hack.csv"
df = pd.read_csv(filepath)

# %%
years = df["Year"].value_counts()
years.plot(kind='bar')
plt.ylabel('Numbers of Rows')
plt.xlabel('Year')
plt.title('Number of Rows Associated with a Certain Year') 
plt.show()
print(years)

categories = df["Category"].value_counts()
categories.plot(kind='bar')
plt.ylabel("Number of Rows")
plt.xlabel("Type of Exchange")
plt.title("Number of Rows Associated with Exchange")
plt.show()
print(categories)
# Out:
# Year
# 2022    4018
# 2023    1958
# Name: count, dtype: int64
# Category
# Cost       2496
# Revenue    1872
# Expense    1608
# Name: count, dtype: int64

# %%
##
## OVERALL
##

revenue = df2022[df2022['Category'] == "Revenue"]["Amount"]
rev_avg, rev_med, rev_std = revenue.mean(), revenue.median(), revenue.std()
plt.hist(revenue, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Revenue Histogram')
plt.show()

print("Revenue\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (rev_avg, rev_med, rev_std))

expense = df[df['Category'] == "Expense"]["Amount"]
exp_avg, exp_med, exp_std = expense.mean(), expense.median(), expense.std()


plt.hist(expense, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Expense Histogram')
plt.show()

print("Expense\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (exp_avg, exp_med, exp_std))


cost = df[df['Category'] == "Cost"]["Amount"]
cost_avg, cost_med, cost_std = cost.mean(), cost.median(), cost.std()

plt.hist(cost, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Cost Histogram')
plt.show()

print("Cost\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (cost_avg, cost_med, cost_std))
# Out:
# Revenue
#  Average: 7353.13, Median: 7207.20, Standard Deviation: 4815.51
# Expense
#  Average: 5434.86, Median: 5650.00, Standard Deviation: 2714.24
# Cost
#  Average: 3268.81, Median: 3156.30, Standard Deviation: 2666.40

# %%
##
## 2022
##

print("DATA FOR 2022")

df2022 = df[df["Year"] == 2022]
revenue = df2022[df2022['Category'] == "Revenue"]["Amount"]
rev_avg, rev_med, rev_std = revenue.mean(), revenue.median(), revenue.std()
plt.hist(revenue, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Revenue Histogram')
plt.show()

print("Revenue\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (rev_avg, rev_med, rev_std))


expense = df2022[df2022['Category'] == "Expense"]["Amount"]
exp_avg, exp_med, exp_std = expense.mean(), expense.median(), expense.std()

plt.hist(expense, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Expense Histogram')
plt.show()

print("Expense\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (exp_avg, exp_med, exp_std))


cost = df2022[df2022['Category'] == "Cost"]["Amount"]
cost_avg, cost_med, cost_std = cost.mean(), cost.median(), cost.std()

plt.hist(cost, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Cost Histogram')
plt.show()

print("Cost\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (cost_avg, cost_med, cost_std))
# Out:
# DATA FOR 2022
# Revenue
#  Average: 7353.13, Median: 7207.20, Standard Deviation: 4815.51
# Expense
#  Average: 5293.30, Median: 5586.00, Standard Deviation: 2559.81
# Cost
#  Average: 3175.29, Median: 3153.15, Standard Deviation: 1840.25

# %%
##
## 2023
##

print("DATA FOR 2023")

df2023 = df[df["Year"] == 2023]
revenue = df2023[df2023['Category'] == "Revenue"]["Amount"]
rev_avg, rev_med, rev_std = revenue.mean(), revenue.median(), revenue.std()
plt.hist(revenue, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Revenue Histogram')
plt.show()

print("Revenue\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (rev_avg, rev_med, rev_std))


expense = df2023[df2023['Category'] == "Expense"]["Amount"]
exp_avg, exp_med, exp_std = expense.mean(), expense.median(), expense.std()

plt.hist(expense, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Expense Histogram')
plt.show()
print("Expense\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (exp_avg, exp_med, exp_std))


cost = df2023[df2023['Category'] == "Cost"]["Amount"]
cost_avg, cost_med, cost_std = cost.mean(), cost.median(), cost.std()

plt.hist(cost, bins=25, edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Cost Histogram')
plt.show()
print("Cost\n Average: %.2f, Median: %.2f, Standard Deviation: %.2f\n" % (cost_avg, cost_med, cost_std))
# Out:
# DATA FOR 2023
# Revenue
#  Average: 7163.06, Median: 6792.50, Standard Deviation: 6236.17
# Expense
#  Average: 5717.97, Median: 5801.50, Standard Deviation: 2981.74
# Cost
#  Average: 3476.89, Median: 3156.30, Standard Deviation: 3917.30
